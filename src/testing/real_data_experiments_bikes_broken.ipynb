# %%
using PyPlot

# dataset info http://lib.stat.cmu.edu/datasets/boston
# dataset https://github.com/selva86/datasets/blob/master/BostonHousing.csv
# row.temp, row.hum,row.windspeed,row.mnth as the features, count per day as what we are trying to predict

cd("C:\\Users\\Anastasia\\Documents\\GitHub\\multidimensional-segmented-regression\\src")
include("real_experiments_bikes.jl")
# Out:
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = import_sklearn() at Skcore.jl:120
# └ @ ScikitLearn.Skcore C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\ScikitLearn\HK6Vs\src\Skcore.jl:120
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = top-level scope at Skcore.jl:158
# └ @ Core C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\ScikitLearn\HK6Vs\src\Skcore.jl:158
# num samples 731
# num leaves merging 210
# mse merging NaN
# mse cart 1.0553570730599968e6
# time merging 5.580109106
# time cart 1.180153358

# %%
plt.scatter(y, yhat_merging) 
plt.plot([0,8000],[0,8000],"black")
xlabel("True count")
ylabel("Predicted count")
plt.show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.scatter(y, yhat_cart) 
plt.plot([0,8000],[0,8000],"black")
xlabel("True count")
ylabel("Predicted count")
plt.show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
@sk_import metrics: r2_score
println(r2_score(y,yhat_merging))
println(r2_score(y, yhat_cart))
# Out:
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = import_sklearn() at Skcore.jl:120
# └ @ ScikitLearn.Skcore C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\ScikitLearn\HK6Vs\src\Skcore.jl:120
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = top-level scope at Skcore.jl:158
# └ @ Core C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\ScikitLearn\HK6Vs\src\Skcore.jl:158
# PyError ($(Expr(:escape, :(ccall(#= C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\pyfncall.jl:44 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'ValueError'>
# ValueError("Input contains NaN, infinity or a value too large for dtype('float64').",)
#   File "C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\conda\3\lib\site-packages\sklearn\metrics\regression.py", line 534, in r2_score
#     y_true, y_pred, multioutput)
#   File "C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\conda\3\lib\site-packages\sklearn\metrics\regression.py", line 77, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False)
#   File "C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\conda\3\lib\site-packages\sklearn\utils\validation.py", line 573, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\conda\3\lib\site-packages\sklearn\utils\validation.py", line 56, in _assert_all_finite
#     raise ValueError(msg_err.format(type_err, X.dtype))
#
#
# Stacktrace:
#  [1] pyerr_check at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\exception.jl:60 [inlined]
#  [2] pyerr_check at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\exception.jl:64 [inlined]
#  [3] macro expansion at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\exception.jl:84 [inlined]
#  [4] __pycall!(::PyCall.PyObject, ::Ptr{PyCall.PyObject_struct}, ::PyCall.PyObject, ::Ptr{Nothing}) at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\pyfncall.jl:44
#  [5] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{Array{Float64,1},Array{Float64,1}}, ::Int64, ::Ptr{Nothing}) at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\pyfncall.jl:29
#  [6] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{Array{Float64,1},Array{Float64,1}}, ::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\pyfncall.jl:11
#  [7] #call#111(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::PyCall.PyObject, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\pyfncall.jl:89
#  [8] (::PyCall.PyObject)(::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at C:\Users\Anastasia\.juliapro\JuliaPro_v1.0.3.1\packages\PyCall\ttONZ\src\pyfncall.jl:89
#  [9] top-level scope at In[4]:2
